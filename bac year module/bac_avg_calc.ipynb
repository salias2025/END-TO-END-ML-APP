# %%
from IPython.display import display, HTML

html_code = """
<!DOCTYPE html>
<html dir="rtl" lang="ar">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>جدول المواد - السنة الثالثة ثانوي</title>
    <style>
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }
        
        body {
            font-family: 'Cairo', 'Tahoma', 'Segoe UI', sans-serif;
            background: linear-gradient(135deg, #f5f7fa 0%, #e9ecef 100%);
            padding: 30px;
        }
        
        .container {
            max-width: 1400px;
            margin: 0 auto;
            background: white;
            border-radius: 20px;
            box-shadow: 0 20px 40px rgba(0,0,0,0.1);
            overflow: hidden;
            animation: fadeIn 0.5s ease-out;
        }
        
        @keyframes fadeIn {
            from { opacity: 0; transform: translateY(20px); }
            to { opacity: 1; transform: translateY(0); }
        }
        
        .header {
            background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%);
            color: white;
            padding: 25px 30px;
            text-align: center;
        }
        
        .header h1 {
            font-size: 28px;
            margin-bottom: 8px;
            font-weight: 700;
        }
        
        .header p {
            font-size: 14px;
            opacity: 0.9;
            margin: 0;
        }
        
        .badge {
            background: rgba(255,255,255,0.2);
            border-radius: 20px;
            padding: 5px 12px;
            font-size: 12px;
            display: inline-block;
            margin-top: 10px;
        }
        
        table {
            width: 100%;
            border-collapse: collapse;
            font-size: 13px;
        }
        
        th {
            background: linear-gradient(135deg, #2c3e50 0%, #34495e 100%);
            color: white;
            padding: 14px 8px;
            font-weight: 600;
            text-align: center;
            border: 1px solid #3d5a73;
            font-size: 14px;
        }
        
        td {
            padding: 10px 6px;
            text-align: center;
            border: 1px solid #e0e0e0;
            vertical-align: middle;
        }
        
        .subject-cell {
            background: #f8f9fa;
            font-weight: 600;
            text-align: right;
            padding-right: 15px;
            color: #2c3e50;
            border-right: 3px solid #3498db;
            width: 160px;
        }
        
        .time-cell {
            background-color: #fff8e1;
            font-weight: 500;
        }
        
        .coef-cell {
            background-color: #e8f5e9;
            font-weight: 500;
        }
        
        .subject-group {
            background: #f0f7ff;
        }
        
        .summary-row {
            background: linear-gradient(135deg, #2ecc71 0%, #27ae60 100%);
            color: white;
            font-weight: bold;
        }
        
        .summary-row td {
            background: linear-gradient(135deg, #2ecc71 0%, #27ae60 100%);
            color: white;
            border-color: #3d8b40;
            font-size: 14px;
        }
        
        .special-badge {
            background-color: #ff9800;
            color: white;
            border-radius: 12px;
            padding: 2px 8px;
            font-size: 11px;
            display: inline-block;
            margin-left: 5px;
        }
        
        .stream-header {
            background: #1a5276;
        }
        
        tr:hover td {
            background-color: #f5f5f5;
            transition: 0.2s;
        }
        
        .subject-cell:hover {
            background: #e3f2fd;
        }
        
        .footer-note {
            background: #f8f9fa;
            padding: 15px 25px;
            border-top: 1px solid #dee2e6;
            font-size: 12px;
            color: #6c757d;
            text-align: center;
        }
        
        .note-highlight {
            color: #e74c3c;
            font-weight: bold;
        }
        
        @media (max-width: 768px) {
            table {
                font-size: 11px;
            }
            th, td {
                padding: 8px 4px;
            }
            .subject-cell {
                width: 120px;
            }
        }
        
        .tooltip-info {
            cursor: help;
            border-bottom: 1px dashed #999;
        }
    </style>
</head>
<body>
<div class="container">
    <div class="header">
        <h1>📊 جدول أوقات ومعاملات المواد</h1>
        <p>السنة الثالثة ثانوي - جميع الشعب</p>
        <div class="badge">🎓 التعليم الثانوي - الجزائر</div>
    </div>
    
    <table>
        <thead>
            <tr>
                <th>المواد / الشعب</th>
                <th>علوم تجريبية</th>
                <th>رياضيات</th>
                <th>تقني رياضي</th>
                <th>تسيير واقتصاد</th>
                <th>لغات أجنبية</th>
                <th>آداب وفلسفة</th>
            </tr>
        </thead>
        <tbody>
            <!-- اللغة العربية -->
            <tr>
                <td class="subject-cell">📖 اللغة العربية</td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ 3</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ 3</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ 3</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ 3</span></td>
                <td>⏱️ 5<br><span style="color:#e67e22;">⭐ 5</span></td>
                <td>⏱️ 6<br><span style="color:#e67e22;">⭐ 7</span></td>
            </tr>
            
            <!-- اللغة الإنجليزية -->
            <tr>
                <td class="subject-cell">🇬🇧 اللغة الإنجليزية</td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 4<br><span style="color:#e67e22;">⭐ 5</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ 3</span></td>
            </tr>
            
            <!-- اللغة الفرنسية -->
            <tr>
                <td class="subject-cell">🇫🇷 اللغة الفرنسية</td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 4<br><span style="color:#e67e22;">⭐ 4</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ 3</span></td>
            </tr>
            
            <!-- اللغة الألمانية/الإسبانية -->
            <tr>
                <td class="subject-cell">🇩🇪 الألمانية/الإسبانية</td>
                <td>—</td>
                <td>—</td>
                <td>—</td>
                <td>—</td>
                <td>⏱️ 4<br><span style="color:#e67e22;">⭐ 5</span></td>
                <td>—</td>
            </tr>
            
            <!-- الرياضيات -->
            <tr>
                <td class="subject-cell">🧮 الرياضيات</td>
                <td>⏱️ 5<br><span style="color:#e67e22;">⭐ 7</span></td>
                <td>⏱️ 6<br><span style="color:#e67e22;">⭐ 6</span></td>
                <td>⏱️ 4<br><span style="color:#e67e22;">⭐ 5</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
            </tr>
            
            <!-- العلوم الطبيعية -->
            <tr>
                <td class="subject-cell">🔬 العلوم الطبيعية</td>
                <td>⏱️ 5<br><span style="color:#e67e22;">⭐ 6</span></td>
                <td>—</td>
                <td>—</td>
                <td>—</td>
                <td>—</td>
                <td>—</td>
            </tr>
            
            <!-- العلوم الفيزيائية -->
            <tr>
                <td class="subject-cell">⚡ العلوم الفيزيائية</td>
                <td>⏱️ 5<br><span style="color:#e67e22;">⭐ 5</span></td>
                <td>⏱️ 5<br><span style="color:#e67e22;">⭐ 6</span></td>
                <td>—</td>
                <td>—</td>
                <td>—</td>
                <td>—</td>
            </tr>
            
            <!-- التاريخ والجغرافيا -->
            <tr>
                <td class="subject-cell">📜 التاريخ والجغرافيا</td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 4<br><span style="color:#e67e22;">⭐ 4</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 4<br><span style="color:#e67e22;">⭐ 4</span></td>
            </tr>
            
            <!-- العلوم الإسلامية -->
            <tr>
                <td class="subject-cell">🕌 العلوم الإسلامية</td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
            </tr>
            
            <!-- الفلسفة -->
            <tr>
                <td class="subject-cell">💭 الفلسفة</td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>⏱️ 4<br><span style="color:#e67e22;">⭐ 6</span></td>
            </tr>
            
            <!-- التكنولوجيا -->
            <tr>
                <td class="subject-cell">💻 التكنولوجيا</td>
                <td>—</td>
                <td>—</td>
                <td>⏱️ 6<br><span style="color:#e67e22;">⭐ 7</span></td>
                <td>—</td>
                <td>—</td>
                <td>—</td>
            </tr>
            
            <!-- الاقتصاد والمناجمنت -->
            <tr>
                <td class="subject-cell">📈 الاقتصاد والمناجمنت</td>
                <td>—</td>
                <td>—</td>
                <td>—</td>
                <td>⏱️ 4<br><span style="color:#e67e22;">⭐ 5</span></td>
                <td>—</td>
                <td>—</td>
            </tr>
            
            <!-- القانون -->
            <tr>
                <td class="subject-cell">⚖️ القانون</td>
                <td>—</td>
                <td>—</td>
                <td>—</td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 2</span></td>
                <td>—</td>
                <td>—</td>
            </tr>
            
            <!-- التسيير المحاسبي والمالي -->
            <tr>
                <td class="subject-cell">📊 التسيير المحاسبي والمالي</td>
                <td>—</td>
                <td>—</td>
                <td>—</td>
                <td>⏱️ 4<br><span style="color:#e67e22;">⭐ 6</span></td>
                <td>—</td>
                <td>—</td>
            </tr>
            
            <!-- التربية البدنية -->
            <tr>
                <td class="subject-cell">🏃 التربية البدنية</td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 1</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 1</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 1</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 1</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 1</span></td>
                <td>⏱️ 2<br><span style="color:#e67e22;">⭐ 1</span></td>
            </tr>
            
            <!-- الأمازيغية -->
            <tr>
                <td class="subject-cell">ⵜⴰⵎⴰⵣⵉⵖⵜ الأمازيغية</td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ (2)</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ (2)</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ (2)</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ (2)</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ (2)</span></td>
                <td>⏱️ 3<br><span style="color:#e67e22;">⭐ (2)</span></td>
            </tr>
        </tbody>
    </table>
    
    <!-- Table 2: Summary -->
    <div class="header" style="background: linear-gradient(135deg, #2ecc71 0%, #27ae60 100%); margin-top: 5px;">
        <h2 style="font-size: 22px;">📊 ملخص المجموع والمعاملات</h2>
    </div>
    
    <table>
        <thead>
            <tr>
                <th>الشعب</th>
                <th>علوم تجريبية</th>
                <th>رياضيات</th>
                <th>تقني رياضي</th>
                <th>تسيير واقتصاد</th>
                <th>لغات أجنبية</th>
                <th>آداب وفلسفة</th>
            </tr>
        </thead>
        <tbody>
            <tr class="summary-row">
                <td class="subject-cell">📅 مجموع الساعات الأسبوعية</td>
                <td>32 + (2) = <strong style="font-size: 18px;">34</strong></td>
                <td>29 + (2) = <strong style="font-size: 18px;">31</strong></td>
                <td>33 + (2) = <strong style="font-size: 18px;">35</strong></td>
                <td>31 + (2) = <strong style="font-size: 18px;">33</strong></td>
                <td>32 + (2) = <strong style="font-size: 18px;">34</strong></td>
                <td>27 + (2) = <strong style="font-size: 18px;">29</strong></td>
            </tr>
            <tr class="summary-row" style="background: linear-gradient(135deg, #27ae60 0%, #219653 100%);">
                <td class="subject-cell">⭐ مجموع المعاملات</td>
                <td>30 + (2) = <strong style="font-size: 18px;">32</strong></td>
                <td>29 + (2) = <strong style="font-size: 18px;">31</strong></td>
                <td>33 + (2) = <strong style="font-size: 18px;">35</strong></td>
                <td>31 + (2) = <strong style="font-size: 18px;">33</strong></td>
                <td>32 + (2) = <strong style="font-size: 18px;">34</strong></td>
                <td>27 + (2) = <strong style="font-size: 18px;">29</strong></td>
            </tr>
        </tbody>
    </table>
    
    <div class="footer-note">
        <p>📌 <strong>ملاحظات:</strong></p>
        <p>• القيم بين قوسين <span class="note-highlight">(2)</span> تمثل حصة اللغة الأمازيغية (ساعتان إضافيتان + معامل 2)</p>
        <p>• ⏱️ = التوقيت الأسبوعي (ساعات) | ⭐ = المعامل</p>
        <p>• <span class="special-badge">—</span> تعني أن المادة غير مطروحة في هذه الشعبة</p>
        <p class="tooltip-info">📅 المجموع يحسب بإضافة 2 ساعة للأمازيغية (إجبارية لجميع الشعب)</p>
    </div>
</div>
</body>
</html>
"""

display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html dir="rtl" lang="ar">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>جدول المواد - السنة الثالثة ثانوي</title>
#     <style>
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         }
#
#         body {
#             font-family: 'Cairo', 'Tahoma', 'Segoe UI', sans-serif;
#             background: linear-gradient(135deg, #f5f7fa 0%, #e9ecef 100%);
#             padding: 30px;
#         }
#
#         .container {
#             max-width: 1400px;
#             margin: 0 auto;
#             background: white;
#             border-radius: 20px;
#             box-shadow: 0 20px 40px rgba(0,0,0,0.1);
#             overflow: hidden;
#             animation: fadeIn 0.5s ease-out;
#         }
#
#         @keyframes fadeIn {
#             from { opacity: 0; transform: translateY(20px); }
# ...

# %%
from IPython.display import display, HTML

# Define the data for each stream
streams_data = {
    "علوم تجريبية": [
        {"subject": "اللغة العربية", "coef": 3, "grade": "___"},
        {"subject": "اللغة الإنجليزية", "coef": 2, "grade": "___"},
        {"subject": "اللغة الفرنسية", "coef": 2, "grade": "___"},
        {"subject": "الرياضيات", "coef": 7, "grade": "___"},
        {"subject": "العلوم الطبيعية", "coef": 6, "grade": "___"},
        {"subject": "العلوم الفيزيائية", "coef": 5, "grade": "___"},
        {"subject": "التاريخ والجغرافيا", "coef": 2, "grade": "___"},
        {"subject": "العلوم الإسلامية", "coef": 2, "grade": "___"},
        {"subject": "الفلسفة", "coef": 2, "grade": "___"},
        {"subject": "التربية البدنية", "coef": 1, "grade": "___"},
        {"subject": "الأمازيغية", "coef": 2, "grade": "___"}
    ],
    "رياضيات": [
        {"subject": "اللغة العربية", "coef": 3, "grade": "___"},
        {"subject": "اللغة الإنجليزية", "coef": 2, "grade": "___"},
        {"subject": "اللغة الفرنسية", "coef": 2, "grade": "___"},
        {"subject": "الرياضيات", "coef": 6, "grade": "___"},
        {"subject": "العلوم الفيزيائية", "coef": 6, "grade": "___"},
        {"subject": "التاريخ والجغرافيا", "coef": 2, "grade": "___"},
        {"subject": "العلوم الإسلامية", "coef": 2, "grade": "___"},
        {"subject": "الفلسفة", "coef": 2, "grade": "___"},
        {"subject": "التربية البدنية", "coef": 1, "grade": "___"},
        {"subject": "الأمازيغية", "coef": 2, "grade": "___"}
    ],
    "تقني رياضي": [
        {"subject": "اللغة العربية", "coef": 3, "grade": "___"},
        {"subject": "اللغة الإنجليزية", "coef": 2, "grade": "___"},
        {"subject": "اللغة الفرنسية", "coef": 2, "grade": "___"},
        {"subject": "الرياضيات", "coef": 5, "grade": "___"},
        {"subject": "العلوم الفيزيائية", "coef": 5, "grade": "___"},
        {"subject": "التكنولوجيا", "coef": 7, "grade": "___"},
        {"subject": "التاريخ والجغرافيا", "coef": 2, "grade": "___"},
        {"subject": "العلوم الإسلامية", "coef": 2, "grade": "___"},
        {"subject": "الفلسفة", "coef": 2, "grade": "___"},
        {"subject": "التربية البدنية", "coef": 1, "grade": "___"},
        {"subject": "الأمازيغية", "coef": 2, "grade": "___"}
    ],
    "تسيير واقتصاد": [
        {"subject": "اللغة العربية", "coef": 3, "grade": "___"},
        {"subject": "اللغة الإنجليزية", "coef": 2, "grade": "___"},
        {"subject": "اللغة الفرنسية", "coef": 2, "grade": "___"},
        {"subject": "الرياضيات", "coef": 2, "grade": "___"},
        {"subject": "التاريخ والجغرافيا", "coef": 4, "grade": "___"},
        {"subject": "العلوم الإسلامية", "coef": 2, "grade": "___"},
        {"subject": "الفلسفة", "coef": 2, "grade": "___"},
        {"subject": "الاقتصاد والمناجمنت", "coef": 5, "grade": "___"},
        {"subject": "القانون", "coef": 2, "grade": "___"},
        {"subject": "التسيير المحاسبي والمالي", "coef": 6, "grade": "___"},
        {"subject": "التربية البدنية", "coef": 1, "grade": "___"},
        {"subject": "الأمازيغية", "coef": 2, "grade": "___"}
    ],
    "لغات أجنبية": [
        {"subject": "اللغة العربية", "coef": 5, "grade": "___"},
        {"subject": "اللغة الإنجليزية", "coef": 5, "grade": "___"},
        {"subject": "اللغة الفرنسية", "coef": 4, "grade": "___"},
        {"subject": "اللغة الألمانية/الإسبانية", "coef": 5, "grade": "___"},
        {"subject": "الرياضيات", "coef": 2, "grade": "___"},
        {"subject": "التاريخ والجغرافيا", "coef": 2, "grade": "___"},
        {"subject": "العلوم الإسلامية", "coef": 2, "grade": "___"},
        {"subject": "الفلسفة", "coef": 2, "grade": "___"},
        {"subject": "التربية البدنية", "coef": 1, "grade": "___"},
        {"subject": "الأمازيغية", "coef": 2, "grade": "___"}
    ],
    "آداب وفلسفة": [
        {"subject": "اللغة العربية", "coef": 7, "grade": "___"},
        {"subject": "اللغة الإنجليزية", "coef": 3, "grade": "___"},
        {"subject": "اللغة الفرنسية", "coef": 3, "grade": "___"},
        {"subject": "الرياضيات", "coef": 2, "grade": "___"},
        {"subject": "التاريخ والجغرافيا", "coef": 4, "grade": "___"},
        {"subject": "العلوم الإسلامية", "coef": 2, "grade": "___"},
        {"subject": "الفلسفة", "coef": 6, "grade": "___"},
        {"subject": "التربية البدنية", "coef": 1, "grade": "___"},
        {"subject": "الأمازيغية", "coef": 2, "grade": "___"}
    ]
}

# Function to generate HTML table for a stream
def generate_table(stream_name, data):
    html = f"""
    <div style="font-family: 'Cairo', 'Tahoma', sans-serif; direction: rtl; margin: 20px auto; max-width: 800px;">
        <div style="background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%); 
                    color: white; padding: 15px; border-radius: 15px 15px 0 0; text-align: center;">
            <h2 style="margin: 0;">📊 شعبة {stream_name}</h2>
            <p style="margin: 5px 0 0 0; opacity: 0.9;">سجل نقاطك في الجدول أدناه</p>
        </div>
        <div style="overflow-x: auto;">
            <table style="width: 100%; border-collapse: collapse; background: white; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
                <thead>
                    <tr style="background: #2c3e50; color: white;">
                        <th style="padding: 12px; text-align: center; border: 1px solid #34495e;">📖 المادة</th>
                        <th style="padding: 12px; text-align: center; border: 1px solid #34495e;">⭐ المعامل</th>
                        <th style="padding: 12px; text-align: center; border: 1px solid #34495e;">🎯 النقطة (0-20)</th>
                    </tr>
                </thead>
                <tbody>
    """
    
    for i, item in enumerate(data):
        # Alternate row colors
        bg_color = "#f8f9fa" if i % 2 == 0 else "#ffffff"
        html += f"""
                    <tr style="background: {bg_color};">
                        <td style="padding: 10px; text-align: right; border: 1px solid #dee2e6; font-weight: 500;">{item['subject']}</td>
                        <td style="padding: 10px; text-align: center; border: 1px solid #dee2e6; font-weight: bold; color: #e67e22;">{item['coef']}</td>
                        <td style="padding: 8px; text-align: center; border: 1px solid #dee2e6;">
                            <input type="text" style="width: 80px; padding: 8px; text-align: center; border: 2px solid #3498db; border-radius: 8px; font-size: 14px;" placeholder="__" value="{item['grade'] if item['grade'] != '___' else ''}">
                        </td>
                    </tr>
        """
    
    # Calculate total coefficients
    total_coef = sum(item['coef'] for item in data)
    
    html += f"""
                    <tr style="background: #e8f8f5; font-weight: bold;">
                        <td style="padding: 12px; text-align: right; border: 1px solid #dee2e6;">📅 المجموع</td>
                        <td style="padding: 12px; text-align: center; border: 1px solid #dee2e6; color: #27ae60; font-size: 18px;">{total_coef}</td>
                        <td style="padding: 12px; text-align: center; border: 1px solid #dee2e6;">
                            <button onclick="calculateAverage(this)" style="background: #27ae60; color: white; border: none; padding: 8px 20px; border-radius: 8px; cursor: pointer; font-size: 14px;">
                                📊 احسب المعدل
                            </button>
                        </td>
                    </tr>
                </tbody>
            </table>
        </div>
    </div>
    """
    
    return html

# Create dropdown for stream selection
stream_dropdown = widgets.Dropdown(
    options=list(streams_data.keys()),
    value="تسيير واقتصاد",
    description='🇩🇿 الشعبة:',
    style={'description_width': '80px'},
    layout=widgets.Layout(width='400px', margin='10px auto')
)

# Output area
output = widgets.Output()

# JavaScript function for calculation
js_code = """
<script>
function calculateAverage(button) {
    var row = button.parentElement.parentElement;
    var table = row.parentElement.parentElement.parentElement;
    var rows = table.getElementsByTagName('tr');
    var totalPoints = 0;
    var totalCoef = 0;
    
    for (var i = 0; i < rows.length - 1; i++) {
        var cells = rows[i].getElementsByTagName('td');
        if (cells.length >= 3) {
            var coef = parseFloat(cells[1].innerText);
            var gradeInput = cells[2].getElementsByTagName('input')[0];
            var grade = parseFloat(gradeInput.value);
            
            if (!isNaN(grade) && grade >= 0 && grade <= 20) {
                totalPoints += grade * coef;
                totalCoef += coef;
            }
        }
    }
    
    if (totalCoef > 0) {
        var average = totalPoints / totalCoef;
        var resultRow = document.createElement('div');
        resultRow.style.cssText = 'margin-top: 20px; padding: 20px; border-radius: 10px; text-align: center; font-family: Cairo, Tahoma, sans-serif;';
        
        var color = average >= 16 ? '#2ecc71' : (average >= 14 ? '#27ae60' : (average >= 12 ? '#f39c12' : (average >= 10 ? '#e67e22' : '#e74c3c')));
        resultRow.style.background = 'linear-gradient(135deg, ' + color + ' 0%, ' + color + '80 100%)';
        resultRow.style.color = 'white';
        
        var emoji = average >= 16 ? '🏆' : (average >= 14 ? '🎉' : (average >= 12 ? '👍' : (average >= 10 ? '📈' : '⚠️')));
        var status = average >= 16 ? 'ممتاز' : (average >= 14 ? 'جيد جداً' : (average >= 12 ? 'جيد' : (average >= 10 ? 'مقبول' : 'يحتاج إلى تحسين')));
        
        resultRow.innerHTML = '<div style=\"font-size: 18px;\">معدلك في البكالوريا</div>' +
                              '<div style=\"font-size: 48px; font-weight: bold;\">' + average.toFixed(2) + '<span style=\"font-size: 20px;\">/20</span></div>' +
                              '<div style=\"font-size: 16px;\">' + emoji + ' ' + status + ' ' + emoji + '</div>';
        
        var existingResult = document.getElementById('average-result');
        if (existingResult) existingResult.remove();
        resultRow.id = 'average-result';
        table.parentElement.appendChild(resultRow);
    } else {
        alert('الرجاء إدخال نقاط صحيحة (من 0 إلى 20)');
    }
}
</script>
"""

# Display the UI
def display_table(change=None):
    output.clear_output(wait=True)
    with output:
        display(HTML(js_code))
        display(HTML(generate_table(stream_dropdown.value, streams_data[stream_dropdown.value])))

# Observe dropdown changes
stream_dropdown.observe(display_table, names='value')

# Initial display
print("=" * 60)
print("🎓 حاسبة معدل البكالوريا - الجزائر")
print("=" * 60)
print("اختر شعبتك ثم أدخل نقاطك في الجدول لحساب معدلك")
print("-" * 60)

display(stream_dropdown)
display_table()
display(output)
# Out:
# ...
# 🎓 حاسبة معدل البكالوريا - الجزائر
# ...
# اختر شعبتك ثم أدخل نقاطك في الجدول لحساب معدلك
# ------------------------------------------------------------
# Dropdown(description='🇩🇿 الشعبة:', index=3, layout=Layout(margin='10px auto', width='400px'), options=('علوم ت…
# Output()

# %%
from IPython.display import display, HTML

html_resources = """
<!DOCTYPE html>
<html dir="rtl" lang="ar">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>منصة توصيات الموارد التعليمية - البكالوريا</title>
    <style>
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }
        
        body {
            font-family: 'Cairo', 'Tahoma', 'Segoe UI', sans-serif;
            background: linear-gradient(135deg, #f5f7fa 0%, #e9ecef 100%);
            padding: 30px;
        }
        
        .container {
            max-width: 1400px;
            margin: 0 auto;
        }
        
        /* Header */
        .header {
            background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%);
            color: white;
            padding: 40px 30px;
            border-radius: 20px;
            text-align: center;
            margin-bottom: 30px;
            box-shadow: 0 10px 30px rgba(0,0,0,0.1);
        }
        
        .header h1 {
            font-size: 32px;
            margin-bottom: 10px;
        }
        
        .header p {
            font-size: 16px;
            opacity: 0.9;
        }
        
        .badge {
            background: rgba(255,255,255,0.2);
            border-radius: 30px;
            padding: 8px 20px;
            display: inline-block;
            margin-top: 15px;
            font-size: 14px;
        }
        
        /* Stream Selector */
        .stream-selector {
            background: white;
            padding: 20px;
            border-radius: 15px;
            margin-bottom: 30px;
            box-shadow: 0 4px 15px rgba(0,0,0,0.08);
            text-align: center;
        }
        
        .stream-selector label {
            font-size: 18px;
            font-weight: 600;
            color: #2c3e50;
            margin-left: 15px;
        }
        
        select {
            padding: 10px 20px;
            font-size: 16px;
            border: 2px solid #3498db;
            border-radius: 10px;
            background: white;
            font-family: 'Cairo', sans-serif;
            cursor: pointer;
            transition: all 0.3s;
        }
        
        select:hover {
            border-color: #2ecc71;
        }
        
        /* Subject Selector */
        .subject-selector {
            background: linear-gradient(135deg, #f8f9fa 0%, #fff 100%);
            padding: 15px 20px;
            border-radius: 15px;
            margin-bottom: 30px;
            box-shadow: 0 4px 15px rgba(0,0,0,0.08);
            display: flex;
            flex-wrap: wrap;
            gap: 10px;
            justify-content: center;
        }
        
        .subject-btn {
            background: #ecf0f1;
            border: none;
            padding: 10px 20px;
            border-radius: 30px;
            font-family: 'Cairo', sans-serif;
            font-size: 14px;
            cursor: pointer;
            transition: all 0.3s;
            color: #2c3e50;
        }
        
        .subject-btn:hover {
            background: #3498db;
            color: white;
            transform: translateY(-2px);
        }
        
        .subject-btn.active {
            background: #2ecc71;
            color: white;
            box-shadow: 0 4px 10px rgba(46,204,113,0.3);
        }
        
        /* Resource Grid */
        .resource-grid {
            display: grid;
            grid-template-columns: repeat(auto-fill, minmax(350px, 1fr));
            gap: 25px;
            margin-bottom: 40px;
        }
        
        /* Resource Card */
        .resource-card {
            background: white;
            border-radius: 20px;
            overflow: hidden;
            box-shadow: 0 10px 25px rgba(0,0,0,0.08);
            transition: all 0.3s;
            cursor: pointer;
            position: relative;
        }
        
        .resource-card:hover {
            transform: translateY(-5px);
            box-shadow: 0 20px 35px rgba(0,0,0,0.15);
        }
        
        .card-header {
            padding: 20px;
            color: white;
            position: relative;
        }
        
        .card-icon {
            font-size: 40px;
            margin-bottom: 10px;
        }
        
        .card-title {
            font-size: 20px;
            font-weight: 700;
            margin-bottom: 5px;
        }
        
        .card-subtitle {
            font-size: 12px;
            opacity: 0.9;
        }
        
        .card-body {
            padding: 20px;
        }
        
        .card-description {
            color: #666;
            font-size: 14px;
            line-height: 1.6;
            margin-bottom: 15px;
        }
        
        .card-meta {
            display: flex;
            justify-content: space-between;
            align-items: center;
            border-top: 1px solid #eee;
            padding-top: 15px;
            margin-top: 10px;
        }
        
        .rating {
            color: #f39c12;
            font-size: 14px;
        }
        
        .tag {
            background: #ecf0f1;
            padding: 4px 12px;
            border-radius: 20px;
            font-size: 11px;
            color: #2c3e50;
        }
        
        .card-footer {
            padding: 15px 20px;
            background: #f8f9fa;
            border-top: 1px solid #eee;
            display: flex;
            justify-content: space-between;
            align-items: center;
        }
        
        .btn-link {
            background: #3498db;
            color: white;
            border: none;
            padding: 8px 20px;
            border-radius: 25px;
            cursor: pointer;
            font-family: 'Cairo', sans-serif;
            font-size: 13px;
            transition: all 0.3s;
            text-decoration: none;
            display: inline-block;
        }
        
        .btn-link:hover {
            background: #2980b9;
            transform: scale(1.05);
        }
        
        .btn-favorite {
            background: none;
            border: none;
            font-size: 20px;
            cursor: pointer;
            color: #e74c3c;
            transition: all 0.3s;
        }
        
        .btn-favorite:hover {
            transform: scale(1.2);
        }
        
        /* Category Header */
        .category-section {
            margin-bottom: 30px;
        }
        
        .category-title {
            font-size: 24px;
            font-weight: 700;
            color: #2c3e50;
            margin-bottom: 20px;
            padding-right: 15px;
            border-right: 5px solid #e74c3c;
        }
        
        /* Recommendations Panel */
        .recommendations-panel {
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            border-radius: 20px;
            padding: 30px;
            margin-top: 30px;
            color: white;
            text-align: center;
        }
        
        .recommendations-panel h3 {
            font-size: 24px;
            margin-bottom: 15px;
        }
        
        .recommendations-list {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            gap: 15px;
            margin-top: 20px;
        }
        
        .rec-tag {
            background: rgba(255,255,255,0.2);
            padding: 10px 20px;
            border-radius: 40px;
            font-size: 14px;
            cursor: pointer;
            transition: all 0.3s;
        }
        
        .rec-tag:hover {
            background: rgba(255,255,255,0.4);
            transform: scale(1.05);
        }
        
        /* Footer */
        .footer {
            text-align: center;
            padding: 30px;
            color: #888;
            font-size: 12px;
        }
        
        @media (max-width: 768px) {
            .resource-grid {
                grid-template-columns: 1fr;
            }
            .subject-btn {
                padding: 6px 12px;
                font-size: 12px;
            }
        }
    </style>
</head>
<body>
<div class="container">
    <!-- Header -->
    <div class="header">
        <h1>📚 منصة توصيات الموارد التعليمية</h1>
        <p>أفضل القنوات، الكتب، التطبيقات، والدورات لمساعدتك في البكالوريا</p>
        <div class="badge">🎯 توصيات مبنية على تحليل بيانات حقيقية</div>
    </div>
    
    <!-- Stream Selector -->
    <div class="stream-selector">
        <label>🎓 اختر شعبتك:</label>
        <select id="streamSelect">
            <option value="all">🌍 جميع الشعب</option>
            <option value="sciences">🔬 علوم تجريبية</option>
            <option value="math">📐 رياضيات</option>
            <option value="tech">⚙️ تقني رياضي</option>
            <option value="gestion">📊 تسيير واقتصاد</option>
            <option value="langues">🌐 لغات أجنبية</option>
            <option value="lettres">📖 آداب وفلسفة</option>
        </select>
    </div>
    
    <!-- Subject Selector -->
    <div class="subject-selector" id="subjectSelector">
        <button class="subject-btn active" data-subject="all">📚 جميع المواد</button>
        <button class="subject-btn" data-subject="math">🧮 رياضيات</button>
        <button class="subject-btn" data-subject="physics">⚡ فيزياء</button>
        <button class="subject-btn" data-subject="science">🔬 علوم</button>
        <button class="subject-btn" data-subject="arabic">📖 لغة عربية</button>
        <button class="subject-btn" data-subject="english">🇬🇧 إنجليزية</button>
        <button class="subject-btn" data-subject="french">🇫🇷 فرنسية</button>
        <button class="subject-btn" data-subject="history">📜 تاريخ وجغرافيا</button>
        <button class="subject-btn" data-subject="islam">🕌 إسلامية</button>
        <button class="subject-btn" data-subject="philo">💭 فلسفة</button>
        <button class="subject-btn" data-subject="gestion">📊 تسيير</button>
        <button class="subject-btn" data-subject="eco">📈 اقتصاد</button>
        <button class="subject-btn" data-subject="law">⚖️ قانون</button>
    </div>
    
    <!-- YouTube Channels Section -->
    <div class="category-section">
        <div class="category-title">🎬 قنوات يوتيوب موصى بها</div>
        <div class="resource-grid" id="youtubeGrid"></div>
    </div>
    
    <!-- Books Section -->
    <div class="category-section">
        <div class="category-title">📖 كتب وملخصات PDF</div>
        <div class="resource-grid" id="booksGrid"></div>
    </div>
    
    <!-- Apps Section -->
    <div class="category-section">
        <div class="category-title">📱 تطبيقات مفيدة</div>
        <div class="resource-grid" id="appsGrid"></div>
    </div>
    
    <!-- Social Media Section -->
    <div class="category-section">
        <div class="category-title">🌐 صفحات فيسبوك وإنستغرام</div>
        <div class="resource-grid" id="socialGrid"></div>
    </div>
    
    <!-- Courses Section -->
    <div class="category-section">
        <div class="category-title">🎓 دورات تدريبية (Zoom/Teams)</div>
        <div class="resource-grid" id="coursesGrid"></div>
    </div>
    
    <!-- Recommendations Panel -->
    <div class="recommendations-panel">
        <h3>🎯 توصيات مخصصة لك</h3>
        <p>بناءً على مستواك ونقاط ضعفك، ننصحك بـ:</p>
        <div class="recommendations-list" id="recommendationsList">
            <div class="rec-tag">📐 مراجعة قواعد الرياضيات</div>
            <div class="rec-tag">📊 تمارين تسيير التكاليف</div>
            <div class="rec-tag">🕌 حفظ الأحاديث النبوية</div>
            <div class="rec-tag">📜 تحليل خرائط التاريخ</div>
        </div>
    </div>
    
    <!-- Footer -->
    <div class="footer">
        <p>✨ هذه التوصيات مبنية على تحليل أداء طلاب البكالوريا في السنوات السابقة ✨</p>
    </div>
</div>

<script>
    // Resource Data
    const resources = {
        youtube: [
            { name: "أستاذ عبد الله - الرياضيات", subject: "math", streams: ["all", "math", "tech", "sciences"], rating: 4.8, description: "شرح مبسط لقواعد الرياضيات مع تمارين محلولة", url: "#", icon: "📐" },
            { name: "الباك فيزياء", subject: "physics", streams: ["all", "sciences", "math", "tech"], rating: 4.7, description: "دروس الفيزياء مع تجارب تطبيقية", url: "#", icon: "⚡" },
            { name: "العلوم الطبيعية - باك 2025", subject: "science", streams: ["all", "sciences"], rating: 4.6, description: "ملخصات وشروحات لمادة العلوم", url: "#", icon: "🔬" },
            { name: "قناة اللغة العربية", subject: "arabic", streams: ["all"], rating: 4.5, description: "قواعد النحو والصرف وتحليل النصوص", url: "#", icon: "📖" },
            { name: "English Bac 2025", subject: "english", streams: ["all", "langues"], rating: 4.4, description: "دروس الإنجليزية مع تمارين ومواضيع", url: "#", icon: "🇬🇧" },
            { name: "Français Bac", subject: "french", streams: ["all", "langues"], rating: 4.3, description: "شرح قواعد الفرنسية ومنهجية المقال", url: "#", icon: "🇫🇷" },
            { name: "تاريخ وجغرافيا - BAC", subject: "history", streams: ["all"], rating: 4.5, description: "تحليل الخرائط والوثائق التاريخية", url: "#", icon: "📜" },
            { name: "العلوم الإسلامية - BAC", subject: "islam", streams: ["all"], rating: 4.6, description: "تفسير الآيات وتحليل الأحاديث", url: "#", icon: "🕌" },
            { name: "فلسفة - BAC", subject: "philo", streams: ["all"], rating: 4.4, description: "منهجية المقال الفلسفي", url: "#", icon: "💭" },
            { name: "تسيير محاسبي ومالي", subject: "gestion", streams: ["all", "gestion"], rating: 4.7, description: "حل مسائل التسيير والمحاسبة", url: "#", icon: "📊" },
            { name: "اقتصاد ومناجمنت", subject: "eco", streams: ["all", "gestion"], rating: 4.5, description: "تحليل الوضعيات الاقتصادية", url: "#", icon: "📈" },
            { name: "قانون - بكالوريا", subject: "law", streams: ["all", "gestion"], rating: 4.3, description: "شرح قواعد القانون", url: "#", icon: "⚖️" }
        ],
        books: [
            { name: "ملخصات الأستاذ", subject: "all", streams: ["all"], rating: 4.7, description: "ملخصات شاملة لجميع المواد بصيغة PDF", url: "#", icon: "📘" },
            { name: "تمارين محلولة - رياضيات", subject: "math", streams: ["all", "math", "tech", "sciences"], rating: 4.6, description: "300 تمرين محلول في الرياضيات", url: "#", icon: "📐" },
            { name: "الموجز في الفلسفة", subject: "philo", streams: ["all"], rating: 4.5, description: "ملخص المفاهيم الفلسفية والفلاسفة", url: "#", icon: "💭" },
            { name: "أطلس التاريخ والجغرافيا", subject: "history", streams: ["all"], rating: 4.4, description: "خرائط تاريخية وجغرافية محللة", url: "#", icon: "🗺️" }
        ],
        apps: [
            { name: "BAC 2025 - جميع المواد", subject: "all", streams: ["all"], rating: 4.6, description: "تطبيق شامل لمراجعة البكالوريا", url: "#", icon: "📱" },
            { name: "Math Solver", subject: "math", streams: ["all"], rating: 4.5, description: "حل المعادلات والتمارين الرياضية", url: "#", icon: "📐" },
            { name: "Quiz Bac", subject: "all", streams: ["all"], rating: 4.4, description: "اختبارات تفاعلية لجميع المواد", url: "#", icon: "🎯" }
        ],
        social: [
            { name: "صفحة BAC 2025 - فيسبوك", subject: "all", streams: ["all"], rating: 4.5, description: "مجموعة دعم للطلاب", url: "#", icon: "📘" },
            { name: "Insta Bac - إنستغرام", subject: "all", streams: ["all"], rating: 4.3, description: "ملخصات يومية ونصائح", url: "#", icon: "📸" },
            { name: "Telegram Bac - قناة", subject: "all", streams: ["all"], rating: 4.4, description: "قناة تلغرام للمراجعة", url: "#", icon: "💬" }
        ],
        courses: [
            { name: "دورة تسيير المحاسبة - Zoom", subject: "gestion", streams: ["all", "gestion"], rating: 4.8, description: "دورة مكثفة لتسيير المحاسبة", url: "#", icon: "📊" },
            { name: "دورة الفلسفة - Teams", subject: "philo", streams: ["all"], rating: 4.6, description: "منهجية كتابة المقال الفلسفي", url: "#", icon: "💭" },
            { name: "دورة الرياضيات المتقدمة", subject: "math", streams: ["all", "math", "tech", "sciences"], rating: 4.7, description: "مراجعة شاملة للرياضيات", url: "#", icon: "📐" },
            { name: "دورة الاقتصاد والمناجمنت", subject: "eco", streams: ["all", "gestion"], rating: 4.5, description: "تحليل الوضعيات الاقتصادية", url: "#", icon: "📈" }
        ]
    };
    
    // Function to render cards
    function renderCards(containerId, items, filters) {
        const container = document.getElementById(containerId);
        if (!container) return;
        
        const filtered = items.filter(item => {
            if (filters.subject !== 'all' && item.subject !== filters.subject && item.subject !== 'all') return false;
            if (filters.stream !== 'all' && !item.streams.includes(filters.stream) && !item.streams.includes('all')) return false;
            return true;
        });
        
        if (filtered.length === 0) {
            container.innerHTML = '<div style="text-align: center; padding: 40px; background: #f8f9fa; border-radius: 15px;">📭 لا توجد موارد متاحة حالياً</div>';
            return;
        }
        
        container.innerHTML = filtered.map(item => `
            <div class="resource-card">
                <div class="card-header" style="background: linear-gradient(135deg, #3498db 0%, #2980b9 100%);">
                    <div class="card-icon">${item.icon}</div>
                    <div class="card-title">${item.name}</div>
                    <div class="card-subtitle">${item.subject === 'all' ? 'كل المواد' : item.subject}</div>
                </div>
                <div class="card-body">
                    <div class="card-description">${item.description}</div>
                    <div class="card-meta">
                        <div class="rating">⭐ ${item.rating}/5</div>
                        <div class="tag">${item.subject === 'all' ? '📚 شامل' : '📘 ' + item.subject}</div>
                    </div>
                </div>
                <div class="card-footer">
                    <button class="btn-link" onclick="window.open('${item.url}', '_blank')">🔗 زيارة المورد</button>
                    <button class="btn-favorite" onclick="alert('تمت الإضافة إلى المفضلة 📌')">❤️</button>
                </div>
            </div>
        `).join('');
    }
    
    // Current filters
    let currentFilters = {
        stream: 'all',
        subject: 'all'
    };
    
    // Render all sections
    function renderAll() {
        renderCards('youtubeGrid', resources.youtube, currentFilters);
        renderCards('booksGrid', resources.books, currentFilters);
        renderCards('appsGrid', resources.apps, currentFilters);
        renderCards('socialGrid', resources.social, currentFilters);
        renderCards('coursesGrid', resources.courses, currentFilters);
    }
    
    // Stream selector handler
    document.getElementById('streamSelect').addEventListener('change', (e) => {
        currentFilters.stream = e.target.value;
        renderAll();
    });
    
    // Subject selector handlers
    document.querySelectorAll('.subject-btn').forEach(btn => {
        btn.addEventListener('click', () => {
            document.querySelectorAll('.subject-btn').forEach(b => b.classList.remove('active'));
            btn.classList.add('active');
            currentFilters.subject = btn.dataset.subject;
            renderAll();
        });
    });
    
    // Initial render
    renderAll();
</script>
</body>
</html>
"""

display(HTML(html_resources))
# Out:
# <!DOCTYPE html>
# <html dir="rtl" lang="ar">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>منصة توصيات الموارد التعليمية - البكالوريا</title>
#     <style>
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         }
#
#         body {
#             font-family: 'Cairo', 'Tahoma', 'Segoe UI', sans-serif;
#             background: linear-gradient(135deg, #f5f7fa 0%, #e9ecef 100%);
#             padding: 30px;
#         }
#
#         .container {
#             max-width: 1400px;
#             margin: 0 auto;
#         }
#
#         /* Header */
#         .header {
#             background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%);
#             color: white;
#             padding: 40px 30px;
#             border-radius: 20px;
#             text-align: center;
#             margin-bottom: 30px;
# ...

# %%
from IPython.display import display, HTML

html_budget = """
<!DOCTYPE html>
<html dir="rtl" lang="ar">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>حاسبة ميزانية تحضير البكالوريا</title>
    <style>
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }
        
        body {
            font-family: 'Cairo', 'Tahoma', 'Segoe UI', sans-serif;
            background: linear-gradient(135deg, #f0f4f8 0%, #d9e2ec 100%);
            padding: 30px;
        }
        
        .container {
            max-width: 1400px;
            margin: 0 auto;
        }
        
        /* Header */
        .header {
            background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%);
            color: white;
            padding: 35px 30px;
            border-radius: 20px;
            text-align: center;
            margin-bottom: 30px;
            box-shadow: 0 10px 30px rgba(0,0,0,0.1);
        }
        
        .header h1 {
            font-size: 32px;
            margin-bottom: 10px;
        }
        
        .header p {
            font-size: 16px;
            opacity: 0.9;
        }
        
        .budget-total {
            background: rgba(255,255,255,0.2);
            border-radius: 30px;
            padding: 10px 25px;
            display: inline-block;
            margin-top: 15px;
            font-size: 20px;
        }
        
        /* Budget Summary Cards */
        .summary-cards {
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(200px, 1fr));
            gap: 20px;
            margin-bottom: 30px;
        }
        
        .summary-card {
            background: white;
            padding: 20px;
            border-radius: 15px;
            text-align: center;
            box-shadow: 0 4px 15px rgba(0,0,0,0.08);
            transition: all 0.3s;
        }
        
        .summary-card:hover {
            transform: translateY(-3px);
        }
        
        .summary-card h3 {
            font-size: 14px;
            color: #666;
            margin-bottom: 10px;
        }
        
        .summary-card .amount {
            font-size: 28px;
            font-weight: bold;
            color: #2c3e50;
        }
        
        .summary-card .percentage {
            font-size: 12px;
            color: #888;
            margin-top: 5px;
        }
        
        /* Main Content Layout */
        .main-content {
            display: flex;
            gap: 25px;
            flex-wrap: wrap;
        }
        
        .expenses-section {
            flex: 2;
            min-width: 300px;
        }
        
        .chart-section {
            flex: 1;
            min-width: 300px;
        }
        
        /* Expense Categories */
        .category-card {
            background: white;
            border-radius: 20px;
            margin-bottom: 20px;
            overflow: hidden;
            box-shadow: 0 4px 15px rgba(0,0,0,0.08);
            transition: all 0.3s;
        }
        
        .category-header {
            padding: 20px;
            display: flex;
            align-items: center;
            gap: 15px;
            cursor: pointer;
            transition: all 0.3s;
        }
        
        .category-icon {
            font-size: 35px;
            width: 60px;
            height: 60px;
            background: #f8f9fa;
            border-radius: 15px;
            display: flex;
            align-items: center;
            justify-content: center;
        }
        
        .category-info {
            flex: 1;
        }
        
        .category-name {
            font-size: 18px;
            font-weight: 700;
            color: #2c3e50;
        }
        
        .category-desc {
            font-size: 12px;
            color: #888;
        }
        
        .category-amount {
            text-align: left;
        }
        
        .amount-input {
            width: 120px;
            padding: 10px;
            border: 2px solid #e0e0e0;
            border-radius: 10px;
            font-size: 16px;
            text-align: center;
            font-family: 'Cairo', sans-serif;
            transition: all 0.3s;
        }
        
        .amount-input:focus {
            border-color: #3498db;
            outline: none;
        }
        
        .category-progress {
            background: #ecf0f1;
            height: 4px;
            width: 100%;
        }
        
        .progress-bar {
            height: 100%;
            transition: width 0.5s;
        }
        
        .category-footer {
            padding: 15px 20px;
            background: #f8f9fa;
            display: flex;
            justify-content: space-between;
            font-size: 13px;
            color: #666;
        }
        
        /* Budget Summary */
        .budget-summary {
            background: white;
            border-radius: 20px;
            padding: 25px;
            box-shadow: 0 4px 15px rgba(0,0,0,0.08);
            margin-bottom: 20px;
            text-align: center;
        }
        
        .budget-summary h3 {
            color: #2c3e50;
            margin-bottom: 15px;
        }
        
        .total-budget {
            font-size: 48px;
            font-weight: bold;
            color: #2ecc71;
            margin: 15px 0;
        }
        
        .remaining {
            font-size: 24px;
            color: #e74c3c;
            margin: 10px 0;
        }
        
        .savings-tip {
            background: #e8f8f5;
            padding: 15px;
            border-radius: 15px;
            margin-top: 15px;
            text-align: right;
            font-size: 13px;
            color: #0e6655;
        }
        
        /* Simple Chart */
        .pie-chart {
            margin: 20px 0;
        }
        
        .legend {
            margin-top: 20px;
        }
        
        .legend-item {
            display: flex;
            align-items: center;
            gap: 10px;
            margin-bottom: 10px;
            font-size: 12px;
        }
        
        .legend-color {
            width: 20px;
            height: 20px;
            border-radius: 4px;
        }
        
        /* Recommendations */
        .recommendations-box {
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            border-radius: 20px;
            padding: 25px;
            color: white;
            margin-top: 30px;
        }
        
        .recommendations-box h4 {
            margin-bottom: 15px;
            font-size: 18px;
        }
        
        .rec-list {
            list-style: none;
            padding: 0;
        }
        
        .rec-list li {
            padding: 8px 0;
            display: flex;
            align-items: center;
            gap: 10px;
            font-size: 14px;
        }
        
        /* Buttons */
        .action-buttons {
            display: flex;
            gap: 15px;
            justify-content: center;
            margin-top: 30px;
        }
        
        .btn {
            padding: 12px 30px;
            border: none;
            border-radius: 30px;
            font-family: 'Cairo', sans-serif;
            font-size: 14px;
            cursor: pointer;
            transition: all 0.3s;
        }
        
        .btn-primary {
            background: #2ecc71;
            color: white;
        }
        
        .btn-primary:hover {
            background: #27ae60;
            transform: scale(1.05);
        }
        
        .btn-secondary {
            background: #e74c3c;
            color: white;
        }
        
        .btn-secondary:hover {
            background: #c0392b;
        }
        
        .footer {
            text-align: center;
            padding: 30px;
            color: #888;
            font-size: 12px;
        }
        
        @media (max-width: 768px) {
            .category-header {
                flex-wrap: wrap;
            }
            .category-amount {
                width: 100%;
                text-align: right;
                margin-top: 10px;
            }
        }
    </style>
</head>
<body>
<div class="container">
    <!-- Header -->
    <div class="header">
        <h1>💰 حاسبة ميزانية تحضير البكالوريا</h1>
        <p>خطط ميزانيتك بذكاء لتحقيق أفضل النتائج</p>
        <div class="budget-total">📊 الميزانية الإجمالية: <span id="totalBudget">500000</span> دج</div>
    </div>
    
    <!-- Summary Cards -->
    <div class="summary-cards">
        <div class="summary-card">
            <h3>💸 المصروفات الشهرية</h3>
            <div class="amount" id="monthlyExpenses">0</div>
            <div class="percentage">دج</div>
        </div>
        <div class="summary-card">
            <h3>📚 المواد الدراسية</h3>
            <div class="amount" id="booksAmount">0</div>
            <div class="percentage">دج</div>
        </div>
        <div class="summary-card">
            <h3>🎓 الدروس الخصوصية</h3>
            <div class="amount" id="tutoringAmount">0</div>
            <div class="percentage">دج</div>
        </div>
        <div class="summary-card">
            <h3>💡 الإلكترونيات</h3>
            <div class="amount" id="electronicsAmount">0</div>
            <div class="percentage">دج</div>
        </div>
    </div>
    
    <div class="main-content">
        <!-- Left Section: Expenses -->
        <div class="expenses-section">
            <!-- Private Tutoring -->
            <div class="category-card">
                <div class="category-header">
                    <div class="category-icon">🎓</div>
                    <div class="category-info">
                        <div class="category-name">الدروس الخصوصية</div>
                        <div class="category-desc">دروس تقوية، مراجعة مع أساتذة</div>
                    </div>
                    <div class="category-amount">
                        <input type="number" class="amount-input" id="tutoring" placeholder="المبلغ" value="150000" step="10000">
                    </div>
                </div>
                <div class="category-progress">
                    <div class="progress-bar" id="tutoringProgress" style="width: 0%; background: #e74c3c;"></div>
                </div>
                <div class="category-footer">
                    <span>💡 نصيحة: يمكن تقليل التكاليف بالدروس الجماعية</span>
                    <span>🎯 الأهمية: ⭐⭐⭐⭐⭐</span>
                </div>
            </div>
            
            <!-- Books and Documents -->
            <div class="category-card">
                <div class="category-header">
                    <div class="category-icon">📚</div>
                    <div class="category-info">
                        <div class="category-name">الكتب والوثائق</div>
                        <div class="category-desc">كتب مدرسية، ملخصات، وثائق PDF</div>
                    </div>
                    <div class="category-amount">
                        <input type="number" class="amount-input" id="books" placeholder="المبلغ" value="80000" step="5000">
                    </div>
                </div>
                <div class="category-progress">
                    <div class="progress-bar" id="booksProgress" style="width: 0%; background: #3498db;"></div>
                </div>
                <div class="category-footer">
                    <span>💡 نصيحة: استخدم المكتبات الرقمية المجانية</span>
                    <span>🎯 الأهمية: ⭐⭐⭐⭐</span>
                </div>
            </div>
            
            <!-- Dawarat/Online Courses -->
            <div class="category-card">
                <div class="category-header">
                    <div class="category-icon">💻</div>
                    <div class="category-info">
                        <div class="category-name">دورات Zoom/Teams</div>
                        <div class="category-desc">دورات تدريبية أونلاين، مراجعة جماعية</div>
                    </div>
                    <div class="category-amount">
                        <input type="number" class="amount-input" id="courses" placeholder="المبلغ" value="100000" step="10000">
                    </div>
                </div>
                <div class="category-progress">
                    <div class="progress-bar" id="coursesProgress" style="width: 0%; background: #f39c12;"></div>
                </div>
                <div class="category-footer">
                    <span>💡 نصيحة: ابحث عن دورات مجانية على يوتيوب</span>
                    <span>🎯 الأهمية: ⭐⭐⭐⭐</span>
                </div>
            </div>
            
            <!-- Electronics/Devices -->
            <div class="category-card">
                <div class="category-header">
                    <div class="category-icon">📱</div>
                    <div class="category-info">
                        <div class="category-name">أجهزة ومواد إلكترونية</div>
                        <div class="category-desc">تابلت، كمبيوتر، طابعة، إنترنت</div>
                    </div>
                    <div class="category-amount">
                        <input type="number" class="amount-input" id="electronics" placeholder="المبلغ" value="70000" step="10000">
                    </div>
                </div>
                <div class="category-progress">
                    <div class="progress-bar" id="electronicsProgress" style="width: 0%; background: #9b59b6;"></div>
                </div>
                <div class="category-footer">
                    <span>💡 نصيحة: استثمر في جهاز جيد للدراسة الأونلاين</span>
                    <span>🎯 الأهمية: ⭐⭐⭐</span>
                </div>
            </div>
            
            <!-- Transportation -->
            <div class="category-card">
                <div class="category-header">
                    <div class="category-icon">🚗</div>
                    <div class="category-info">
                        <div class="category-name">المواصلات</div>
                        <div class="category-desc">تنقلات إلى الدروس والمكتبات</div>
                    </div>
                    <div class="category-amount">
                        <input type="number" class="amount-input" id="transport" placeholder="المبلغ" value="50000" step="5000">
                    </div>
                </div>
                <div class="category-progress">
                    <div class="progress-bar" id="transportProgress" style="width: 0%; background: #1abc9c;"></div>
                </div>
                <div class="category-footer">
                    <span>💡 نصيحة: الدروس الأونلاين توفر تكاليف النقل</span>
                    <span>🎯 الأهمية: ⭐⭐</span>
                </div>
            </div>
            
            <!-- Stationery -->
            <div class="category-card">
                <div class="category-header">
                    <div class="category-icon">✏️</div>
                    <div class="category-info">
                        <div class="category-name">القرطاسية</div>
                        <div class="category-desc">أقلام، دفاتر، ألوان، آلة حاسبة</div>
                    </div>
                    <div class="category-amount">
                        <input type="number" class="amount-input" id="stationery" placeholder="المبلغ" value="30000" step="5000">
                    </div>
                </div>
                <div class="category-progress">
                    <div class="progress-bar" id="stationeryProgress" style="width: 0%; background: #e84393;"></div>
                </div>
                <div class="category-footer">
                    <span>💡 نصيحة: اشترِ الجودة المناسبة وليس الأغلى</span>
                    <span>🎯 الأهمية: ⭐⭐⭐</span>
                </div>
            </div>
            
            <!-- Printing -->
            <div class="category-card">
                <div class="category-header">
                    <div class="category-icon">🖨️</div>
                    <div class="category-info">
                        <div class="category-name">الطباعة والتصوير</div>
                        <div class="category-desc">طباعة ملخصات، امتحانات، وثائق</div>
                    </div>
                    <div class="category-amount">
                        <input type="number" class="amount-input" id="printing" placeholder="المبلغ" value="20000" step="5000">
                    </div>
                </div>
                <div class="category-progress">
                    <div class="progress-bar" id="printingProgress" style="width: 0%; background: #fd79a8;"></div>
                </div>
                <div class="category-footer">
                    <span>💡 نصيحة: استخدم النسخ الرقمية لتوفير الورق</span>
                    <span>🎯 الأهمية: ⭐⭐</span>
                </div>
            </div>
            
            <!-- Food/Snacks -->
            <div class="category-card">
                <div class="category-header">
                    <div class="category-icon">🍎</div>
                    <div class="category-info">
                        <div class="category-name">وجبات ومشروبات</div>
                        <div class="category-desc">وجبات خفيفة، مشروبات للمراجعة</div>
                    </div>
                    <div class="category-amount">
                        <input type="number" class="amount-input" id="food" placeholder="المبلغ" value="40000" step="5000">
                    </div>
                </div>
                <div class="category-progress">
                    <div class="progress-bar" id="foodProgress" style="width: 0%; background: #fdcb6e;"></div>
                </div>
                <div class="category-footer">
                    <span>💡 نصيحة: حضر وجبات منزلية صحية</span>
                    <span>🎯 الأهمية: ⭐⭐</span>
                </div>
            </div>
        </div>
        
        <!-- Right Section: Budget Summary & Chart -->
        <div class="chart-section">
            <div class="budget-summary">
                <h3>📊 ملخص الميزانية</h3>
                <div class="total-budget" id="totalBudgetDisplay">500,000</div>
                <div>إجمالي الميزانية (دج)</div>
                <div class="remaining" id="remainingDisplay">0</div>
                <div>المتبقي (دج)</div>
                <div id="percentageUsed" style="font-size: 14px; margin-top: 10px;"></div>
                <div class="savings-tip" id="savingsTip">
                    💡 استثمر في الدروس الخصوصية للمواد التي تجد صعوبة فيها
                </div>
            </div>
            
            <!-- Simple Donut Chart -->
            <div class="pie-chart" id="pieChart"></div>
            
            <div class="legend" id="legend"></div>
            
            <!-- Action Buttons -->
            <div class="action-buttons">
                <button class="btn btn-primary" onclick="resetBudget()">🔄 إعادة تعيين</button>
                <button class="btn btn-primary" onclick="optimizeBudget()">✨ تحسين الميزانية</button>
                <button class="btn btn-secondary" onclick="exportBudget()">📥 تصدير التقرير</button>
            </div>
        </div>
    </div>
    
    <!-- Recommendations -->
    <div class="recommendations-box" id="recommendations">
        <h4>🎯 توصيات لتحسين ميزانيتك</h4>
        <ul class="rec-list">
            <li>🔹 <strong>الدروس الخصوصية:</strong> يمكنك توفير 30% بالانضمام إلى مجموعات دراسية</li>
            <li>🔹 <strong>الكتب:</strong> ابحث عن نسخ PDF مجانية أو استعر من المكتبات</li>
            <li>🔹 <strong>الدورات:</strong> هناك العديد من القنوات التعليمية المجانية على يوتيوب</li>
            <li>🔹 <strong>الإلكترونيات:</strong> استثمر في جهاز لوحي اقتصادي بدل الكمبيوتر المحمول</li>
        </ul>
    </div>
    
    <div class="footer">
        <p>✨ خطط لميزانيتك بذكاء واستثمر في ما يحسن أدائك الدراسي حقاً ✨</p>
    </div>
</div>

<script>
    // Get all expense inputs
    const inputs = {
        tutoring: document.getElementById('tutoring'),
        books: document.getElementById('books'),
        courses: document.getElementById('courses'),
        electronics: document.getElementById('electronics'),
        transport: document.getElementById('transport'),
        stationery: document.getElementById('stationery'),
        printing: document.getElementById('printing'),
        food: document.getElementById('food')
    };
    
    const colors = {
        tutoring: '#e74c3c',
        books: '#3498db',
        courses: '#f39c12',
        electronics: '#9b59b6',
        transport: '#1abc9c',
        stationery: '#e84393',
        printing: '#fd79a8',
        food: '#fdcb6e'
    };
    
    let totalBudget = 500000;
    
    // Calculate total expenses
    function calculateTotal() {
        let total = 0;
        for (let key in inputs) {
            let val = parseInt(inputs[key].value) || 0;
            total += val;
        }
        return total;
    }
    
    // Update progress bars
    function updateProgress() {
        for (let key in inputs) {
            let val = parseInt(inputs[key].value) || 0;
            let percentage = (val / totalBudget) * 100;
            let progressBar = document.getElementById(key + 'Progress');
            if (progressBar) {
                progressBar.style.width = Math.min(percentage, 100) + '%';
            }
        }
    }
    
    // Update summary cards
    function updateSummary() {
        let tutoring = parseInt(inputs.tutoring.value) || 0;
        let books = parseInt(inputs.books.value) || 0;
        let electronics = parseInt(inputs.electronics.value) || 0;
        
        document.getElementById('tutoringAmount').innerText = tutoring.toLocaleString();
        document.getElementById('booksAmount').innerText = books.toLocaleString();
        document.getElementById('electronicsAmount').innerText = electronics.toLocaleString();
        
        let monthly = Math.round((tutoring + books + electronics + (parseInt(inputs.courses.value)||0) + 
            (parseInt(inputs.transport.value)||0) + (parseInt(inputs.stationery.value)||0) + 
            (parseInt(inputs.printing.value)||0) + (parseInt(inputs.food.value)||0)) / 6);
        document.getElementById('monthlyExpenses').innerText = monthly.toLocaleString();
    }
    
    // Update all displays
    function updateAll() {
        let total = calculateTotal();
        let remaining = totalBudget - total;
        let percentage = (total / totalBudget) * 100;
        
        document.getElementById('totalBudgetDisplay').innerText = totalBudget.toLocaleString();
        document.getElementById('remainingDisplay').innerText = remaining.toLocaleString();
        document.getElementById('percentageUsed').innerHTML = `المستخدم: ${percentage.toFixed(1)}% من الميزانية`;
        
        updateProgress();
        updateSummary();
        updateChart();
        updateRecommendations(total, remaining);
        
        // Color code remaining amount
        let remainingEl = document.getElementById('remainingDisplay');
        if (remaining < 0) {
            remainingEl.style.color = '#e74c3c';
            remainingEl.innerText = remaining.toLocaleString() + ' (عجز)';
        } else {
            remainingEl.style.color = remaining < totalBudget * 0.2 ? '#f39c12' : '#2ecc71';
        }
    }
    
    // Update pie chart
    function updateChart() {
        let data = [];
        for (let key in inputs) {
            let val = parseInt(inputs[key].value) || 0;
            if (val > 0) {
                data.push({label: getLabel(key), value: val, color: colors[key]});
            }
        }
        
        if (data.length === 0) {
            document.getElementById('pieChart').innerHTML = '<div style="text-align:center; padding:40px;">لا توجد بيانات</div>';
            document.getElementById('legend').innerHTML = '';
            return;
        }
        
        let total = data.reduce((sum, d) => sum + d.value, 0);
        
        // Create simple bar chart instead of canvas (for compatibility)
        let chartHtml = '<div style="margin: 20px 0;">';
        for (let d of data) {
            let percentage = (d.value / total) * 100;
            chartHtml += `
                <div style="margin-bottom: 12px;">
                    <div style="display: flex; justify-content: space-between; margin-bottom: 4px;">
                        <span style="font-size: 12px;">${d.label}</span>
                        <span style="font-size: 12px;">${percentage.toFixed(1)}%</span>
                    </div>
                    <div style="background: #ecf0f1; border-radius: 10px; height: 20px; overflow: hidden;">
                        <div style="width: ${percentage}%; height: 100%; background: ${d.color}; border-radius: 10px;"></div>
                    </div>
                </div>
            `;
        }
        chartHtml += '</div>';
        
        document.getElementById('pieChart').innerHTML = chartHtml;
        
        // Update legend
        let legendHtml = '<div class="legend"><h4 style="margin-bottom: 10px;">📊 تفاصيل المصروفات</h4>';
        for (let d of data) {
            let percentage = (d.value / total) * 100;
            legendHtml += `
                <div class="legend-item">
                    <div class="legend-color" style="background: ${d.color};"></div>
                    <span style="flex:1;">${d.label}</span>
                    <span>${d.value.toLocaleString()} دج</span>
                    <span style="color:#888;">(${percentage.toFixed(1)}%)</span>
                </div>
            `;
        }
        legendHtml += '</div>';
        document.getElementById('legend').innerHTML = legendHtml;
    }
    
    function getLabel(key) {
        const labels = {
            tutoring: '🎓 دروس خصوصية',
            books: '📚 كتب ووثائق',
            courses: '💻 دورات Zoom',
            electronics: '📱 أجهزة إلكترونية',
            transport: '🚗 مواصلات',
            stationery: '✏️ قرطاسية',
            printing: '🖨️ طباعة',
            food: '🍎 وجبات ومشروبات'
        };
        return labels[key] || key;
    }
    
    // Update recommendations based on spending
    function updateRecommendations(total, remaining) {
        let tutoring = parseInt(inputs.tutoring.value) || 0;
        let books = parseInt(inputs.books.value) || 0;
        let courses = parseInt(inputs.courses.value) || 0;
        
        let recHtml = '<h4>🎯 توصيات مخصصة لميزانيتك</h4><ul class="rec-list">';
        
        if (tutoring > totalBudget * 0.3) {
            recHtml += '<li>🔹 <strong>الدروس الخصوصية:</strong> تشكل أكثر من 30% من ميزانيتك. جرّب الدروس الجماعية لتوفير 40%</li>';
        }
        if (books > totalBudget * 0.15) {
            recHtml += '<li>🔹 <strong>الكتب والوثائق:</strong> يمكنك توفير 50% باستخدام المصادر الرقمية المجانية</li>';
        }
        if (courses > totalBudget * 0.2) {
            recHtml += '<li>🔹 <strong>الدورات التدريبية:</strong> هناك محتوى مجاني ممتاز على يوتيوب بديل عن الدورات المدفوعة</li>';
        }
        if (remaining < 0) {
            recHtml += '<li>⚠️ <strong style="color:#ff6b6b;">عجز في الميزانية!</strong> راجع مصروفاتك وقلل النفقات غير الضرورية</li>';
        } else if (remaining > totalBudget * 0.3) {
            recHtml += '<li>✅ <strong>ممتاز!</strong> لديك فائض في الميزانية. استثمره في مواد تحتاج إلى تقوية أو دورات إضافية</li>';
        } else if (remaining > 0) {
            recHtml += '<li>📌 لديك فائض جيد. فكر في الاستثمار في كتب تمارين محلولة</li>';
        }
        
        if (tutoring > 0 && books === 0) {
            recHtml += '<li>💡 ملاحظة: أنت تنفق على الدروس الخصوصية ولكن ليس على الكتب. الكتب ضرورية للمراجعة الذاتية</li>';
        }
        
        recHtml += '<li>🎯 <strong>نصيحة ذهبية:</strong> استثمر أكثر في المواد التي تجد صعوبة فيها وقلل في المواد التي تتقنها</li>';
        recHtml += '</ul>';
        
        document.getElementById('recommendations').innerHTML = recHtml;
    }
    
    // Reset budget to defaults
    function resetBudget() {
        inputs.tutoring.value = 150000;
        inputs.books.value = 80000;
        inputs.courses.value = 100000;
        inputs.electronics.value = 70000;
        inputs.transport.value = 50000;
        inputs.stationery.value = 30000;
        inputs.printing.value = 20000;
        inputs.food.value = 40000;
        updateAll();
    }
    
    // Optimize budget (AI-style suggestions)
    function optimizeBudget() {
        let currentTotal = calculateTotal();
        if (currentTotal > totalBudget) {
            // Suggest reducing expenses
            inputs.printing.value = Math.max(5000, (parseInt(inputs.printing.value) || 0) * 0.6);
            inputs.stationery.value = Math.max(10000, (parseInt(inputs.stationery.value) || 0) * 0.7);
            inputs.food.value = Math.max(20000, (parseInt(inputs.food.value) || 0) * 0.7);
            inputs.transport.value = Math.max(20000, (parseInt(inputs.transport.value) || 0) * 0.7);
        } else {
            // Suggest optimal allocation
            inputs.tutoring.value = Math.min(200000, (parseInt(inputs.tutoring.value) || 0) + 20000);
            inputs.books.value = Math.min(100000, (parseInt(inputs.books.value) || 0) + 10000);
        }
        updateAll();
        alert('تم تحسين ميزانيتك! ✅');
    }
    
    // Export budget report
    function exportBudget() {
        let total = calculateTotal();
        let remaining = totalBudget - total;
        let report = `📊 تقرير ميزانية البكالوريا\n`;
        report += `━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\n`;
        report += `📅 التاريخ: ${new Date().toLocaleDateString('ar-DZ')}\n`;
        report += `💰 إجمالي الميزانية: ${totalBudget.toLocaleString()} دج\n`;
        report += `💸 إجمالي المصروفات: ${total.toLocaleString()} دج\n`;
        report += `💵 المتبقي: ${remaining.toLocaleString()} دج\n`;
        report += `━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\n`;
        report += `📋 تفاصيل المصروفات:\n`;
        
        for (let key in inputs) {
            let val = parseInt(inputs[key].value) || 0;
            if (val > 0) {
                report += `   • ${getLabel(key)}: ${val.toLocaleString()} دج\n`;
            }
        }
        
        report += `━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\n`;
        report += `🎯 نسبة الاستخدام: ${((total/totalBudget)*100).toFixed(1)}%\n`;
        
        // Create download
        const blob = new Blob([report], {type: 'text/plain'});
        const link = document.createElement('a');
        link.href = URL.createObjectURL(blob);
        link.download = `budget_report_${new Date().toISOString().slice(0,10)}.txt`;
        link.click();
        URL.revokeObjectURL(link.href);
        alert('تم تصدير التقرير بنجاح! 📥');
    }
    
    // Add event listeners
    for (let key in inputs) {
        inputs[key].addEventListener('input', updateAll);
    }
    
    // Initialize
    updateAll();
    
    // Make functions global for buttons
    window.resetBudget = resetBudget;
    window.optimizeBudget = optimizeBudget;
    window.exportBudget = exportBudget;
</script>
</body>
</html>
"""

display(HTML(html_budget))
# Out:
# <!DOCTYPE html>
# <html dir="rtl" lang="ar">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>حاسبة ميزانية تحضير البكالوريا</title>
#     <style>
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         }
#
#         body {
#             font-family: 'Cairo', 'Tahoma', 'Segoe UI', sans-serif;
#             background: linear-gradient(135deg, #f0f4f8 0%, #d9e2ec 100%);
#             padding: 30px;
#         }
#
#         .container {
#             max-width: 1400px;
#             margin: 0 auto;
#         }
#
#         /* Header */
#         .header {
#             background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%);
#             color: white;
#             padding: 35px 30px;
#             border-radius: 20px;
#             text-align: center;
#             margin-bottom: 30px;
#             box-shadow: 0 10px 30px rgba(0,0,0,0.1);
# ...

# %%
from IPython.display import display, HTML

html_timetable = """
<!DOCTYPE html>
<html dir="rtl" lang="ar">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>جدول تنظيم الدراسة - البكالوريا</title>
    <style>
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }
        
        body {
            font-family: 'Cairo', 'Tahoma', 'Segoe UI', sans-serif;
            background: linear-gradient(135deg, #f5f7fa 0%, #e9ecef 100%);
            padding: 30px;
        }
        
        .container {
            max-width: 1400px;
            margin: 0 auto;
        }
        
        /* Header */
        .header {
            background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%);
            color: white;
            padding: 35px 30px;
            border-radius: 20px;
            text-align: center;
            margin-bottom: 30px;
            box-shadow: 0 10px 30px rgba(0,0,0,0.1);
        }
        
        .header h1 {
            font-size: 32px;
            margin-bottom: 10px;
        }
        
        .header p {
            font-size: 16px;
            opacity: 0.9;
        }
        
        .study-tips {
            background: rgba(255,255,255,0.2);
            border-radius: 30px;
            padding: 10px 20px;
            display: inline-block;
            margin-top: 15px;
            font-size: 14px;
        }
        
        /* Controls Bar */
        .controls-bar {
            background: white;
            padding: 20px;
            border-radius: 15px;
            margin-bottom: 30px;
            display: flex;
            flex-wrap: wrap;
            gap: 20px;
            justify-content: space-between;
            align-items: center;
            box-shadow: 0 4px 15px rgba(0,0,0,0.08);
        }
        
        .week-selector {
            display: flex;
            align-items: center;
            gap: 15px;
        }
        
        .week-btn {
            background: #ecf0f1;
            border: none;
            width: 40px;
            height: 40px;
            border-radius: 50%;
            font-size: 20px;
            cursor: pointer;
            transition: all 0.3s;
        }
        
        .week-btn:hover {
            background: #3498db;
            color: white;
        }
        
        .week-display {
            font-size: 18px;
            font-weight: 600;
            color: #2c3e50;
        }
        
        .view-buttons {
            display: flex;
            gap: 10px;
        }
        
        .view-btn {
            padding: 8px 20px;
            border: none;
            border-radius: 25px;
            cursor: pointer;
            font-family: 'Cairo', sans-serif;
            transition: all 0.3s;
            background: #ecf0f1;
        }
        
        .view-btn.active {
            background: #3498db;
            color: white;
        }
        
        .action-buttons {
            display: flex;
            gap: 10px;
        }
        
        .action-btn {
            padding: 8px 20px;
            border: none;
            border-radius: 25px;
            cursor: pointer;
            font-family: 'Cairo', sans-serif;
            transition: all 0.3s;
        }
        
        .btn-export {
            background: #2ecc71;
            color: white;
        }
        
        .btn-reset {
            background: #e74c3c;
            color: white;
        }
        
        /* Timetable Grid */
        .timetable-container {
            background: white;
            border-radius: 20px;
            overflow-x: auto;
            box-shadow: 0 10px 30px rgba(0,0,0,0.1);
        }
        
        .timetable {
            width: 100%;
            border-collapse: collapse;
            min-width: 800px;
        }
        
        .timetable th {
            background: linear-gradient(135deg, #2c3e50 0%, #34495e 100%);
            color: white;
            padding: 15px 10px;
            text-align: center;
            font-weight: 600;
            border: 1px solid #3d5a73;
        }
        
        .timetable td {
            padding: 12px 8px;
            text-align: center;
            border: 1px solid #e0e0e0;
            vertical-align: middle;
        }
        
        .time-slot {
            background: #f8f9fa;
            font-weight: 600;
            color: #2c3e50;
            width: 100px;
        }
        
        .subject-select {
            width: 100%;
            padding: 8px;
            border: 1px solid #ddd;
            border-radius: 8px;
            font-family: 'Cairo', sans-serif;
            font-size: 13px;
            background: white;
            cursor: pointer;
        }
        
        .subject-select option {
            text-align: right;
        }
        
        .break-cell {
            background: #fff3cd;
        }
        
        .study-cell {
            transition: all 0.2s;
        }
        
        .study-cell:hover {
            background: #e3f2fd;
        }
        
        /* Subject Colors */
        .subject-math { background: #ffeaa7; }
        .subject-physics { background: #ffd3b6; }
        .subject-science { background: #b8f2e6; }
        .subject-arabic { background: #d4b8d4; }
        .subject-english { background: #fbc8b5; }
        .subject-french { background: #b5d8ff; }
        .subject-history { background: #c9e4c5; }
        .subject-islam { background: #ffccd5; }
        .subject-philo { background: #e0bbd4; }
        .subject-gestion { background: #ffecb3; }
        .subject-eco { background: #c5e0b4; }
        .subject-law { background: #ffcd94; }
        
        /* Statistics Panel */
        .stats-panel {
            background: white;
            border-radius: 20px;
            padding: 25px;
            margin-top: 30px;
            box-shadow: 0 4px 15px rgba(0,0,0,0.08);
        }
        
        .stats-title {
            font-size: 20px;
            font-weight: 700;
            color: #2c3e50;
            margin-bottom: 20px;
            padding-right: 15px;
            border-right: 4px solid #e74c3c;
        }
        
        .stats-grid {
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(250px, 1fr));
            gap: 20px;
        }
        
        .stat-card {
            background: #f8f9fa;
            padding: 15px;
            border-radius: 15px;
            text-align: center;
        }
        
        .stat-card h4 {
            font-size: 14px;
            color: #666;
            margin-bottom: 10px;
        }
        
        .stat-card .hours {
            font-size: 32px;
            font-weight: bold;
            color: #3498db;
        }
        
        /* Recommendations */
        .recommendations-panel {
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            border-radius: 20px;
            padding: 25px;
            margin-top: 30px;
            color: white;
        }
        
        .recommendations-panel h3 {
            margin-bottom: 15px;
        }
        
        .rec-list {
            list-style: none;
            padding: 0;
        }
        
        .rec-list li {
            padding: 8px 0;
            display: flex;
            align-items: center;
            gap: 10px;
        }
        
        .footer {
            text-align: center;
            padding: 30px;
            color: #888;
            font-size: 12px;
        }
        
        @media (max-width: 768px) {
            .timetable th, .timetable td {
                padding: 8px 4px;
                font-size: 12px;
            }
            .subject-select {
                font-size: 11px;
            }
        }
    </style>
</head>
<body>
<div class="container">
    <!-- Header -->
    <div class="header">
        <h1>📅 جدول تنظيم الدراسة</h1>
        <p>نظم وقتك بذكاء وحقق أفضل النتائج في البكالوريا</p>
        <div class="study-tips">💡 نصيحة: خصص 45-50 دقيقة دراسة + 10 دقائق راحة</div>
    </div>
    
    <!-- Controls Bar -->
    <div class="controls-bar">
        <div class="week-selector">
            <button class="week-btn" onclick="changeWeek(-1)">◀</button>
            <span class="week-display" id="weekDisplay">الأسبوع 1</span>
            <button class="week-btn" onclick="changeWeek(1)">▶</button>
        </div>
        <div class="view-buttons">
            <button class="view-btn active" onclick="changeView('week')">📅 عرض أسبوعي</button>
            <button class="view-btn" onclick="changeView('day')">📆 عرض يومي</button>
        </div>
        <div class="action-buttons">
            <button class="action-btn btn-export" onclick="exportTimetable()">📥 تصدير الجدول</button>
            <button class="action-btn btn-reset" onclick="resetTimetable()">🔄 إعادة تعيين</button>
        </div>
    </div>
    
    <!-- Timetable -->
    <div class="timetable-container">
        <table class="timetable" id="timetable">
            <thead id="tableHeader"></thead>
            <tbody id="tableBody"></tbody>
        </table>
    </div>
    
    <!-- Statistics Panel -->
    <div class="stats-panel">
        <div class="stats-title">📊 إحصائيات الدراسة الأسبوعية</div>
        <div class="stats-grid" id="statsGrid"></div>
    </div>
    
    <!-- Recommendations -->
    <div class="recommendations-panel" id="recommendations">
        <h3>🎯 نصائح وتوصيات لتنظيم وقتك</h3>
        <ul class="rec-list">
            <li>📌 <strong>المراجعة الصباحية:</strong> أفضل وقت للمواد التي تحتاج تركيز (رياضيات، فيزياء)</li>
            <li>📌 <strong>المراجعة المسائية:</strong> مناسبة للمواد النظرية (تاريخ، فلسفة، إسلامية)</li>
            <li>📌 <strong>قاعدة 45/15:</strong> ادرس 45 دقيقة ثم خذ 15 دقيقة راحة</li>
            <li>📌 <strong>لا تنسَ:</strong> خصص وقت للرياضة والترفيه لتجنب الإرهاق</li>
        </ul>
    </div>
    
    <div class="footer">
        <p>✨ جدول مرن - يمكنك تعديل المواد حسب رغبتك ✨</p>
    </div>
</div>

<script>
    // Time slots (8 AM to 10 PM)
    const timeSlots = [
        "08:00 - 09:00", "09:00 - 10:00", "10:00 - 11:00", "11:00 - 12:00",
        "12:00 - 13:00", "13:00 - 14:00", "14:00 - 15:00", "15:00 - 16:00",
        "16:00 - 17:00", "17:00 - 18:00", "18:00 - 19:00", "19:00 - 20:00",
        "20:00 - 21:00", "21:00 - 22:00"
    ];
    
    const days = ["الأحد", "الإثنين", "الثلاثاء", "الأربعاء", "الخميس", "الجمعة", "السبت"];
    
    // Subject options
    const subjects = [
        "", "🧮 رياضيات", "⚡ فيزياء", "🔬 علوم", "📖 لغة عربية", 
        "🇬🇧 إنجليزية", "🇫🇷 فرنسية", "📜 تاريخ وجغرافيا", "🕌 إسلامية", 
        "💭 فلسفة", "📊 تسيير محاسبي", "📈 اقتصاد", "⚖️ قانون", 
        "☕ راحة", "🍽️ استراحة غداء", "🏃 رياضة", "📝 مراجعة عامة"
    ];
    
    // Default timetable data
    let timetableData = {
        0: { // Week 1
            "08:00 - 09:00": ["رياضيات", "فيزياء", "عربية", "رياضيات", "فيزياء", "مراجعة", "راحة"],
            "09:00 - 10:00": ["فيزياء", "رياضيات", "إنجليزية", "فيزياء", "رياضيات", "مراجعة", "راحة"],
            "10:00 - 11:00": ["عربية", "إنجليزية", "رياضيات", "عربية", "إنجليزية", "مراجعة", "راحة"],
            "11:00 - 12:00": ["إنجليزية", "عربية", "فيزياء", "إنجليزية", "عربية", "مراجعة", "راحة"],
            "12:00 - 13:00": ["استراحة", "استراحة", "استراحة", "استراحة", "استراحة", "استراحة", "استراحة"],
            "13:00 - 14:00": ["علوم", "تاريخ", "إسلامية", "علوم", "تاريخ", "مراجعة", "راحة"],
            "14:00 - 15:00": ["تاريخ", "علوم", "فلسفة", "تاريخ", "علوم", "مراجعة", "راحة"],
            "15:00 - 16:00": ["فلسفة", "إسلامية", "علوم", "فلسفة", "إسلامية", "مراجعة", "راحة"],
            "16:00 - 17:00": ["إنجليزية", "فرنسية", "تاريخ", "فرنسية", "فلسفة", "مراجعة", "راحة"],
            "17:00 - 18:00": ["فرنسية", "فلسفة", "فرنسية", "إنجليزية", "فرنسية", "مراجعة", "راحة"],
            "18:00 - 19:00": ["مراجعة", "مراجعة", "مراجعة", "مراجعة", "مراجعة", "مراجعة", "راحة"],
            "19:00 - 20:00": ["تمارين", "تمارين", "تمارين", "تمارين", "تمارين", "مراجعة", "راحة"],
            "20:00 - 21:00": ["مراجعة", "مراجعة", "مراجعة", "مراجعة", "مراجعة", "مراجعة", "راحة"],
            "21:00 - 22:00": ["تخطيط", "تخطيط", "تخطيط", "تخطيط", "تخطيط", "تخطيط", "راحة"]
        }
    };
    
    let currentWeek = 1;
    let currentView = 'week';
    let currentDay = 0;
    
    // Get subject code for display
    function getSubjectCode(subjectName) {
        const map = {
            "رياضيات": "🧮 رياضيات", "فيزياء": "⚡ فيزياء", "علوم": "🔬 علوم",
            "عربية": "📖 لغة عربية", "إنجليزية": "🇬🇧 إنجليزية", "فرنسية": "🇫🇷 فرنسية",
            "تاريخ": "📜 تاريخ وجغرافيا", "إسلامية": "🕌 إسلامية", "فلسفة": "💭 فلسفة",
            "تسيير": "📊 تسيير", "اقتصاد": "📈 اقتصاد", "قانون": "⚖️ قانون",
            "راحة": "☕ راحة", "استراحة": "🍽️ استراحة", "رياضة": "🏃 رياضة",
            "مراجعة": "📝 مراجعة", "تمارين": "✍️ تمارين", "تخطيط": "📅 تخطيط", ""
        };
        return map[subjectName] || subjectName;
    }
    
    // Render timetable
    function renderTimetable() {
        const headerRow = document.getElementById('tableHeader');
        const body = document.getElementById('tableBody');
        
        if (currentView === 'week') {
            // Week view - all days
            headerRow.innerHTML = `<th>الوقت / اليوم</th>${days.map(d => `<th>${d}</th>`).join('')}`;
            
            body.innerHTML = '';
            for (let slot of timeSlots) {
                let row = `<tr><td class="time-slot">${slot}</td>`;
                for (let dayIdx = 0; dayIdx < 7; dayIdx++) {
                    let subject = timetableData[currentWeek]?.[slot]?.[dayIdx] || "";
                    let subjectCode = getSubjectCode(subject);
                    let selectHtml = `<select class="subject-select" data-slot="${slot}" data-day="${dayIdx}" onchange="updateSubject(this)">`;
                    for (let s of subjects) {
                        let selected = (s === subjectCode || (s !== "" && subject.includes(s.replace(/[^\\u0600-\\u06FF ]/g, '').trim()))) ? 'selected' : '';
                        selectHtml += `<option value="${s}" ${selected}>${s || '--- اختر المادة ---'}</option>`;
                    }
                    selectHtml += `</select>`;
                    row += `<td class="study-cell">${selectHtml}</td>`;
                }
                row += `</tr>`;
                body.innerHTML += row;
            }
        } else {
            // Day view
            headerRow.innerHTML = `<th>الوقت</th><th>${days[currentDay]}</th>`;
            
            body.innerHTML = '';
            for (let slot of timeSlots) {
                let subject = timetableData[currentWeek]?.[slot]?.[currentDay] || "";
                let subjectCode = getSubjectCode(subject);
                let selectHtml = `<select class="subject-select" data-slot="${slot}" data-day="${currentDay}" onchange="updateSubject(this)">`;
                for (let s of subjects) {
                    let selected = (s === subjectCode || (s !== "" && subject.includes(s.replace(/[^\\u0600-\\u06FF ]/g, '').trim()))) ? 'selected' : '';
                    selectHtml += `<option value="${s}" ${selected}>${s || '--- اختر المادة ---'}</option>`;
                }
                selectHtml += `</select>`;
                body.innerHTML += `<tr><td class="time-slot">${slot}</td><td class="study-cell">${selectHtml}</td></tr>`;
            }
        }
        
        updateStatistics();
    }
    
    // Update subject in data
    function updateSubject(selectElement) {
        let slot = selectElement.dataset.slot;
        let day = parseInt(selectElement.dataset.day);
        let newValue = selectElement.options[selectElement.selectedIndex].text;
        
        if (!timetableData[currentWeek]) {
            timetableData[currentWeek] = {};
        }
        if (!timetableData[currentWeek][slot]) {
            timetableData[currentWeek][slot] = new Array(7).fill("");
        }
        
        timetableData[currentWeek][slot][day] = newValue;
        updateStatistics();
    }
    
    // Update statistics
    function updateStatistics() {
        let stats = {};
        
        // Count hours per subject
        for (let slot in timetableData[currentWeek]) {
            for (let day = 0; day < 7; day++) {
                let subject = timetableData[currentWeek][slot]?.[day];
                if (subject && subject !== "استراحة" && subject !== "راحة" && subject !== "") {
                    let cleanSubject = subject.replace(/[🧮⚡🔬📖🇬🇧🇫🇷📜🕌💭📊📈⚖️☕🍽️🏃📝✍️📅]/g, '').trim();
                    stats[cleanSubject] = (stats[cleanSubject] || 0) + 1;
                }
            }
        }
        
        // Calculate totals
        let totalHours = Object.values(stats).reduce((a, b) => a + b, 0);
        let studyDays = 0;
        for (let day = 0; day < 7; day++) {
            let dayHasStudy = false;
            for (let slot in timetableData[currentWeek]) {
                let subject = timetableData[currentWeek][slot]?.[day];
                if (subject && subject !== "استراحة" && subject !== "راحة" && subject !== "") {
                    dayHasStudy = true;
                    break;
                }
            }
            if (dayHasStudy) studyDays++;
        }
        
        // Render stats
        let statsHtml = `
            <div class="stat-card">
                <h4>📚 إجمالي ساعات الدراسة</h4>
                <div class="hours">${totalHours}</div>
                <div>ساعة في الأسبوع</div>
            </div>
            <div class="stat-card">
                <h4>📅 أيام الدراسة</h4>
                <div class="hours">${studyDays}</div>
                <div>يوم في الأسبوع</div>
            </div>
            <div class="stat-card">
                <h4>📊 متوسط الساعات يومياً</h4>
                <div class="hours">${studyDays > 0 ? (totalHours / studyDays).toFixed(1) : 0}</div>
                <div>ساعة</div>
            </div>
        `;
        
        // Top subjects
        let sortedStats = Object.entries(stats).sort((a, b) => b[1] - a[1]);
        if (sortedStats.length > 0) {
            statsHtml += `
                <div class="stat-card">
                    <h4>🏆 أكثر مادة درستها</h4>
                    <div class="hours">${sortedStats[0][0]}</div>
                    <div>${sortedStats[0][1]} ساعة</div>
                </div>
            `;
        }
        
        document.getElementById('statsGrid').innerHTML = statsHtml;
        
        // Update recommendations based on stats
        updateRecommendations(totalHours, studyDays, sortedStats);
    }
    
    function updateRecommendations(totalHours, studyDays, topSubjects) {
        let recHtml = '<h3>🎯 نصائح مخصصة لك</h3><ul class="rec-list">';
        
        if (totalHours < 30) {
            recHtml += '<li>⚠️ <strong>عدد ساعات الدراسة قليل:</strong> حاول زيادة ساعات الدراسة إلى 35-40 ساعة أسبوعياً</li>';
        } else if (totalHours > 55) {
            recHtml += '<li>⚠️ <strong>عدد ساعات الدراسة كبير جداً:</strong> لا تنسَ أخذ قسط كافٍ من الراحة لتجنب الإرهاق</li>';
        } else {
            recHtml += '<li>✅ <strong>ممتاز!</strong> عدد ساعات الدراسة مناسب. استمر بهذا المستوى</li>';
        }
        
        if (studyDays === 7) {
            recHtml += '<li>📌 <strong>تدرس كل أيام الأسبوع:</strong> خصص يوم واحد للراحة التامة لتجديد نشاطك</li>';
        } else if (studyDays < 5) {
            recHtml += '<li>📌 <strong>أيام الدراسة قليلة:</strong> حاول توزيع ساعات الدراسة على 5-6 أيام</li>';
        }
        
        if (topSubjects.length > 0 && topSubjects[0][0]) {
            recHtml += `<li>🎯 <strong>${topSubjects[0][0]}</strong> هي المادة التي تركز عليها أكثر. تأكد من توزيع وقتك على جميع المواد</li>`;
        }
        
        recHtml += '<li>💡 <strong>نصيحة ذهبية:</strong> راجع المواد الصعبة في الصباح عندما يكون تركيزك أعلى</li>';
        recHtml += '<li>📖 خصص وقت للمراجعة الأسبوعية لما درسته خلال الأسبوع</li>';
        recHtml += '</ul>';
        
        document.getElementById('recommendations').innerHTML = recHtml;
    }
    
    // Change week
    function changeWeek(delta) {
        let newWeek = currentWeek + delta;
        if (newWeek >= 1 && newWeek <= 16) {
            currentWeek = newWeek;
            document.getElementById('weekDisplay').innerText = `الأسبوع ${currentWeek}`;
            if (!timetableData[currentWeek]) {
                timetableData[currentWeek] = JSON.parse(JSON.stringify(timetableData[1]));
            }
            renderTimetable();
        }
    }
    
    // Change view
    function changeView(view) {
        currentView = view;
        document.querySelectorAll('.view-btn').forEach(btn => btn.classList.remove('active'));
        event.target.classList.add('active');
        
        if (view === 'day') {
            // Show day selector
            let daySelector = document.createElement('div');
            daySelector.className = 'day-selector';
            daySelector.innerHTML = '<span style="margin-left:10px;">اختر اليوم:</span>';
            for (let i = 0; i < days.length; i++) {
                let btn = document.createElement('button');
                btn.innerText = days[i];
                btn.style.margin = '0 3px';
                btn.style.padding = '5px 10px';
                btn.style.border = 'none';
                btn.style.borderRadius = '20px';
                btn.style.cursor = 'pointer';
                btn.onclick = (function(dayIdx) {
                    return function() { 
                        currentDay = dayIdx; 
                        renderTimetable(); 
                    };
                })(i);
                daySelector.appendChild(btn);
            }
            let existing = document.querySelector('.day-selector');
            if (existing) existing.remove();
            document.querySelector('.controls-bar').appendChild(daySelector);
        } else {
            let existing = document.querySelector('.day-selector');
            if (existing) existing.remove();
        }
        renderTimetable();
    }
    
    // Export timetable
    function exportTimetable() {
        let text = `📅 جدول الدراسة - الأسبوع ${currentWeek}\\n`;
        text += `━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\\n`;
        text += `الوقت\\t${days.join('\\t')}\\n`;
        
        for (let slot of timeSlots) {
            text += `${slot}\\t`;
            for (let day = 0; day < 7; day++) {
                let subject = timetableData[currentWeek]?.[slot]?.[day] || "";
                text += `${subject || '---'}\\t`;
            }
            text += `\\n`;
        }
        
        const blob = new Blob([text], {type: 'text/plain'});
        const link = document.createElement('a');
        link.href = URL.createObjectURL(blob);
        link.download = `timetable_week_${currentWeek}.txt`;
        link.click();
        URL.revokeObjectURL(link.href);
        alert('تم تصدير الجدول بنجاح! 📥');
    }
    
    // Reset timetable
    function resetTimetable() {
        if (confirm('هل أنت متأكد من إعادة تعيين الجدول؟')) {
            timetableData = {
                1: JSON.parse(JSON.stringify(timetableData[1]))
            };
            currentWeek = 1;
            document.getElementById('weekDisplay').innerText = 'الأسبوع 1';
            renderTimetable();
        }
    }
    
    // Make functions global
    window.changeWeek = changeWeek;
    window.changeView = changeView;
    window.exportTimetable = exportTimetable;
    window.resetTimetable = resetTimetable;
    window.updateSubject = updateSubject;
    
    // Initialize
    renderTimetable();
</script>
</body>
</html>
"""

display(HTML(html_timetable))
# Out:
# <!DOCTYPE html>
# <html dir="rtl" lang="ar">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>جدول تنظيم الدراسة - البكالوريا</title>
#     <style>
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         }
#
#         body {
#             font-family: 'Cairo', 'Tahoma', 'Segoe UI', sans-serif;
#             background: linear-gradient(135deg, #f5f7fa 0%, #e9ecef 100%);
#             padding: 30px;
#         }
#
#         .container {
#             max-width: 1400px;
#             margin: 0 auto;
#         }
#
#         /* Header */
#         .header {
#             background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%);
#             color: white;
#             padding: 35px 30px;
#             border-radius: 20px;
#             text-align: center;
#             margin-bottom: 30px;
#             box-shadow: 0 10px 30px rgba(0,0,0,0.1);
# ...
